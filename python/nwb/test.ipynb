# %%
import numpy as np

# %%
sortedDir = r'Z:\sueSu\acuteRecordings\behavior_689514_2024-02-01_18-06-43_sorted_2024-02-07_21-42-57'
file = f'{sortedDir}\curated\experiment1_Record Node 101#Neuropix-PXI-100.ProbeA_recording1\properties\default_qc.npy'
file
# Out:
# 'Z:\\sueSu\\acuteRecordings\\behavior_689514_2024-02-01_18-06-43_sorted_2024-02-07_21-42-57\\curated\\experiment1_Record Node 101#Neuropix-PXI-100.ProbeA_recording1\\properties\\default_qc.npy'

# %%
qc = np.load(file)
len(qc)
# Out:
# 544

# %%
from IPython.display import Image
image_file = "/root/capsule/results/689514_2024-02-01_18-06-43/artifact/unit12.0.png"
Image(image_file)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\zhixi\Anaconda3\envs\playGround\lib\site-packages\IPython\core\display.py:1045, in Image._data_and_metadata(self, always_both)
#    1044 try:
# -> 1045     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1046 except TypeError as e:
#
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\zhixi\Anaconda3\envs\playGround\lib\site-packages\IPython\core\formatters.py:974, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#     971     method = get_real_method(obj, self.print_method)
#     973     if method is not None:
# --> 974         return method(include=include, exclude=exclude)
#     975     return None
# ...
